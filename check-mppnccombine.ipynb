# %% [markdown]
# # Check .nc files generated by mppnccombine-fast match those from mppnccombine
#
# see https://github.com/coecms/mppnccombine-fast/issues/29#issuecomment-441486772
#
# First determine which metadata to ignore by doing
#
# ```
# diff <(ncdump -h /g/data3/hh5/tmp/cosima/access-om2-01/01deg_jra55v13_iaf/output197/ocean/ocean.nc) <(ncdump -h /g/data3/hh5/tmp/cosima/access-om2-01/01deg_jra55v13_iaf/output197/ocean/issue_29.nc)
# ```

# %%
import xarray as xr

# %%
# can't access short from VDI
# ds1 = xr.open_dataset('/short/v45/aek156/access-om2/control/01deg_jra55_iaf/archive/output197/ocean/ocean.nc')
# ds2 = xr.open_dataset('/short/v45/aph502/collate_tenth/issue_29.nc')

# ... so copy files here first
# cp /short/v45/aph502/collate_tenth/issue_29.nc /g/data3/hh5/tmp/cosima/access-om2-01/01deg_jra55v13_iaf/output197/ocean
ds1 = xr.open_dataset('/g/data3/hh5/tmp/cosima/access-om2-01/01deg_jra55v13_iaf/output197/ocean/ocean.nc')
ds2 = xr.open_dataset('/g/data3/hh5/tmp/cosima/access-om2-01/01deg_jra55v13_iaf/output197/ocean/issue_29.nc')
# don't check the following (see diff above)
ds1.attrs.update({'filename': ds2.filename})
ds1.attrs.update({'history': ds2.history})
# ds1.attrs.update({'_NCProperties': ds2._NCProperties})
print(ds1.identical(ds2))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-2c282ba53807> in <module>
#      11 ds1.attrs.update({'history': ds2.history})
#      12 # ds1.attrs.update({'_NCProperties': ds2._NCProperties})
# ---> 13 print(ds1.identical(ds2))
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/dataset.py in identical(self, other)
#    1050         try:
#    1051             return (utils.dict_equiv(self.attrs, other.attrs) and
# -> 1052                     self._all_compat(other, 'identical'))
#    1053         except (TypeError, AttributeError):
#    1054             return False
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-18.10/lib/python3.6/site-packages/xarray/core/dataset.py in _all_compat(self, other, compat_str)
#     999         return (self._coord_names == other._coord_names and
# ...
