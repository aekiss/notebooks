# %%
import cosima_cookbook as cc
session = cc.database.create_session()
expt = '01deg_jra55v140_iaf_cycle4'

# %%
cc.querying.get_variables(session, expt)
# Out:
#                name                                          long_name  \
# 0              adic  natural + anthropogenic dissolved inorganic ca...
# 1       adic_int100  100m-integrated natural + anthropogenic dissol...
# 2       adic_intmld  MLD-integrated natural + anthropogenic dissolv...
# 3    adic_xflux_adv                               rho*dzt*dyt*u*tracer
# 4    adic_yflux_adv                               rho*dzt*dxt*v*tracer
# ..              ...                                                ...
# 421            time                                               time
# 422        xt_ocean                                    tcell longitude
# 423        xu_ocean                                    ucell longitude
# 424        yt_ocean                                     tcell latitude
# 425        yu_ocean                                     ucell latitude
#
#                               units frequency  \
# 0                          mmol/m^3      None
# ...

# %%
cc.querying.getvar(expt, 'adic', session, n=-1)
# Out:
# ---------------------------------------------------------------------------
# VariableNotFoundError                     Traceback (most recent call last)
# /jobfs/48042822.gadi-pbs/ipykernel_3678538/3296836337.py in <cell line: 1>()
# ----> 1 cc.querying.getvar(expt, 'adic', session, n=-1)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cosima_cookbook/querying.py in getvar(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique, **kwargs)
#     327         attrs_unique = {"cell_methods": "time: mean"}
#     328
# --> 329     ncfiles = _ncfiles_for_variable(
#     330         expt,
#     331         variable,
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cosima_cookbook/querying.py in _ncfiles_for_variable(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique)
#     494     # ensure we actually got a result
# ...
